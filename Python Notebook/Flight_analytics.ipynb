# %% [markdown]
# # **Exploratory data analytics on flights departing from New York's thre major airports -LGA, JFK and EWR**
#
# Project Overview:
#  This project focuses on analyzing data related to flights departing from three major airports in New York. Our goal is to uncover important trends and patterns in aviation operations. By leveraging data visualization and statistical analysis, we aim to understand the intricacies of aviation and provide actionable insights

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
f_data=pd.read_csv('/content/drive/MyDrive/DA-Projects/Flight analytics/Data sets/flights_2.csv')
f_data.head()
# Out:
#    id  year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0   0  2013      1    1     517.0             515        2.0     830.0
# 1   1  2013      1    1     533.0             529        4.0     850.0
# 2   2  2013      1    1     542.0             540        2.0     923.0
# 3   3  2013      1    1     544.0             545       -1.0    1004.0
# 4   4  2013      1    1     554.0             600       -6.0     812.0
#
#    sched_arr_time  arr_delay  ... flight  tailnum origin dest air_time  \
# 0             819       11.0  ...   1545   N14228    EWR  IAH    227.0
# 1             830       20.0  ...   1714   N24211    LGA  IAH    227.0
# 2             850       33.0  ...   1141   N619AA    JFK  MIA    160.0
# 3            1022      -18.0  ...    725   N804JB    JFK  BQN    183.0
# 4             837      -25.0  ...    461   N668DN    LGA  ATL    116.0
#
#    distance  hour  minute            time_hour                    name
# 0      1400     5      15  2013-01-01 05:00:00   United Air Lines Inc.
# 1      1416     5      29  2013-01-01 05:00:00   United Air Lines Inc.
# 2      1089     5      40  2013-01-01 05:00:00  American Airlines Inc.
# 3      1576     5      45  2013-01-01 05:00:00         JetBlue Airways
# 4       762     6       0  2013-01-01 06:00:00    Delta Air Lines Inc.
#
# [5 rows x 21 columns]

# %%
fdata=pd.read_csv('/content/drive/MyDrive/DA-Projects/Flight analytics/Data sets/flights_2.csv')
fdata.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-65f3f086d1f9> in <cell line: 1>()
# ----> 1 fdata=pd.read_csv('/content/drive/MyDrive/DA-Projects/Flight analytics/Data sets/flights_2.csv')
#       2 fdata.head()
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fdata=pd.read_csv('/content/drive/MyDrive/DA-Projects/Flight analytics/Data sets/flights_2.csv')
fdata.head()
# Out:
#    id  year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0   0  2013      1    1      5.17            5.15       0.02      8.30
# 1   1  2013      1    1      5.33            5.29       0.04      8.50
# 2   2  2013      1    1      5.42            5.40       0.02      9.23
# 3   3  2013      1    1      5.44            5.45      -0.01     10.04
# 4   4  2013      1    1      5.54            6.00      -0.06      8.12
#
#    sched_arr_time  arr_delay  ... flight  tailnum origin dest air_time  \
# 0            8.19       0.11  ...   1545   N14228    EWR  IAH     2.27
# 1            8.30       0.20  ...   1714   N24211    LGA  IAH     2.27
# 2            8.50       0.33  ...   1141   N619AA    JFK  MIA     2.00
# 3           10.22      -0.18  ...    725   N804JB    JFK  BQN     2.23
# 4            8.37      -0.25  ...    461   N668DN    LGA  ATL     1.16
#
#    distance  hour  minute        time_hour                    name
# 0      1400     5      15  01-01-2013 5.00   United Air Lines Inc.
# 1      1416     5      29  01-01-2013 5.00   United Air Lines Inc.
# 2      1089     5      40  01-01-2013 5.00  American Airlines Inc.
# 3      1576     5      45  01-01-2013 5.00         JetBlue Airways
# 4       762     6       0  01-01-2013 6.00    Delta Air Lines Inc.
#
# [5 rows x 21 columns]

# %%
pd.set_option('display.max_columns',21)
fdata.head()
# Out:
#    id  year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0   0  2013      1    1      5.17            5.15       0.02      8.30
# 1   1  2013      1    1      5.33            5.29       0.04      8.50
# 2   2  2013      1    1      5.42            5.40       0.02      9.23
# 3   3  2013      1    1      5.44            5.45      -0.01     10.04
# 4   4  2013      1    1      5.54            6.00      -0.06      8.12
#
#    sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 0            8.19       0.11      UA    1545  N14228    EWR  IAH      2.27
# 1            8.30       0.20      UA    1714  N24211    LGA  IAH      2.27
# 2            8.50       0.33      AA    1141  N619AA    JFK  MIA      2.00
# 3           10.22      -0.18      B6     725  N804JB    JFK  BQN      2.23
# 4            8.37      -0.25      DL     461  N668DN    LGA  ATL      1.16
#
#    distance  hour  minute        time_hour                    name
# 0      1400     5      15  01-01-2013 5.00   United Air Lines Inc.
# 1      1416     5      29  01-01-2013 5.00   United Air Lines Inc.
# 2      1089     5      40  01-01-2013 5.00  American Airlines Inc.
# 3      1576     5      45  01-01-2013 5.00         JetBlue Airways
# 4       762     6       0  01-01-2013 6.00    Delta Air Lines Inc.

# %% [markdown]
# Problem starement : To evaluate the flights departing from airports to understand the air traffic and delays in departing and arrivals , and busy days/months at the respective airports.

# %%
#Number of flights departing per day
#Number of flights departing per day at each airport
#Number of flights by airline
#maximum flights and minimum flights (Day and Month wise )
#Most connecting destination Airport
#Average,max and min Delay in departure  (Total )
#Average,max and mun  Delay in arrival (Total)
#Average,max and min departure delay per airport
#Average ,Max, min airtime
#Distance covered by flights by airline
#Metrics for airline
 #Flights which covered max and min distance
 #Delay evaluavtion
 #On time arrivals
# Metrics for the airports
#average Delay in departure and arrival
#number of flights per day/month -by airlines
#Air traffic evaluation

# %%
fdata.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-982b3db4a85c> in <cell line: 1>()
# ----> 1 fdata.shape
#
# NameError: name 'fdata' is not defined
